# %%
# %matplotlib inline
import matplotlib.pylab as plt
import numpy as np

import torch
import torch.autograd
from torch.autograd import Variable

y = [1,2,3,-1]
x = [-2,-1,0, 1]

w = Variable(20*torch.randn(3).double(), requires_grad=True)
# learning rate
eta = 0.005

for epoch in range(1000):
    for i in range(len(x)):
        f = w[0]+ w[1]*x[i]+w[2]*x[i]**2
        E = (y[i]-f)**2
        
        # Compute the gradients by automated differentiation
        E.backward()
    
        # For each adjustable parameter 
        # Move along the negative gradient direction
        w.data.add_(-eta * w.grad.data)
        # Reset the gradients, as otherwise they are accumulated in param.grad
        w.grad.zero_()
    
ws = w.data
print(ws)

x = np.linspace(-100,100,1000)
wa = w.detach().numpy() 
y = wa[0]+ wa[1]*x+wa[2]*x**2

plt.plot(x, y)
# Out:
# tensor([ 2.2436, -1.7487, -1.2487], dtype=torch.float64)

# %%
# %matplotlib inline
import matplotlib.pylab as plt
import numpy as np

import torch
import torch.autograd
from torch.autograd import Variable

y = [32,29,49,13,51,28,35]

w = Variable(200*torch.randn(1).double(), requires_grad=True)
# learning rate
eta = 0.005

for epoch in range(1000):
    for i in range(len(y)):
        f = w[0]
        E = (y[i]-f)**2
        
        # Compute the gradients by automated differentiation
        E.backward()

        w.data.add_(-eta * w.grad.data)
        w.grad.zero_()
            
ws = w.data
print(float(ws))
# Out:
# 33.869941278702406

# %%
import matplotlib.pylab as plt
import numpy as np

x = np.linspace(-10,10,100)
y = 1/(1+np.exp(-x))
y1 = np.log(1/(1+np.exp(-x)))


plt.plot(x, y)
plt.plot(x, y1)

plt.show()
